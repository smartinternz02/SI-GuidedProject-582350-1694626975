# %% [markdown]
# # Sarvesh Kumar 21BAI1483 (VIT Chennai)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
plt.scatter(x="total",y="speeding",data=df)
plt.title("total vs speeding")
plt.xlabel("total")
plt.ylabel("speeding")
plt.show()

# %%
df.abbrev.nunique()
# Out:
# 51

# %%
plt.scatter(x="total",y="alcohol",data=df)
plt.title("total vs alcohol")
plt.xlabel("total")
plt.ylabel("alcohol")
plt.show()

# %%
plt.scatter(x="speeding",y="alcohol",data=df)
plt.title("speeding vs alcohol")
plt.xlabel("speeding")
plt.ylabel("alcohol")
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.distplot(df["total"])
# Out:
# <Axes: xlabel='total', ylabel='Density'>

# %%
sns.distplot(df["speeding"])
# Out:
# <Axes: xlabel='speeding', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.boxplot(df['total'])
plt.title("total")
plt.subplot(1,2,2)
sns.boxplot(df['speeding'])
plt.title("speeding")
# Out:
# Text(0.5, 1.0, 'speeding')

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.boxplot(df['not_distracted'])
plt.title("not_distracted")
plt.subplot(1,2,2)
sns.boxplot(df['no_previous'])
plt.title("no_previous")
# Out:
# Text(0.5, 1.0, 'no_previous')

# %%
plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
sns.boxplot(df['ins_premium'])
plt.title("ins_premium")
plt.subplot(1,2,2)
sns.boxplot(df['ins_losses'])
plt.title("ins_losses")
# Out:
# Text(0.5, 1.0, '\tins_losses')

# %%
plt.figure(figsize=(8,10))
sns.barplot(x="total", y="abbrev", data=df, color="b")
# Out:
# <Axes: xlabel='total', ylabel='abbrev'>

# %%
plt.figure(figsize=(8,10))
sns.barplot(x="alcohol", y="abbrev", data=df, color="b")
# Out:
# <Axes: xlabel='alcohol', ylabel='abbrev'>

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))
# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=df,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=df,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)
